# %%
import networkx as nx
import pickle
import numpy as np
import pandas as pd
import scipy as sp
import MDAnalysis as mda
from MDAnalysis.analysis import dihedrals
import MDAnalysis.analysis as analysis
import MDAnalysis.analysis.rms
import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib import cm
# from scipy.signal import find_peaks, peak_prominences
from mpl_toolkits.axes_grid1 import make_axes_locatable
plt.rcParams["font.family"] = "Times New Roman"

import os
import sys
import glob
import pathlib
from scipy import spatial

import glob

# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2

# %%
sys_up = '../sys_up'
sys_down = '../sys_down'

gly2_d2u = '../2-head_pro_gly_tmd_d2u'
gly2_u2d = '../2-head_pro_gly_tmd_u2d'
gly3_d2u = '../3-head_pro_gly_tmd_d2u'
gly3_u2d = '../3-head_pro_gly_tmd_u2d'
gly4_d2u = '../4-head_pro_gly_tmd_d2u'
gly4_u2d = '../4-head_pro_gly_tmd_u2d'
gly5_d2u = '../5-head_pro_gly_tmd_d2u'
gly5_u2d = '../5-head_pro_gly_tmd_u2d'
gly6_d2u = '../6-head_pro_gly_tmd_d2u'
gly6_u2d = '../6-head_pro_gly_tmd_u2d'

nogly2_d2u = '../2-head_pro_nogly_tmd_d2u'
nogly2_u2d = '../2-head_pro_nogly_tmd_u2d'
nogly3_d2u = '../3-head_pro_nogly_tmd_d2u'
nogly3_u2d = '../3-head_pro_nogly_tmd_u2d'
nogly4_d2u = '../4-head_pro_nogly_tmd_d2u'
nogly4_u2d = '../4-head_pro_nogly_tmd_u2d'

equil_gly_down = '../0-tmdminequil_gly_down'
equil_gly_up = '../0-tmdminequil_gly_up'
equil_nogly_down = '../0-tmdminequil_nogly_down'
equil_nogly_up = '../0-tmdminequil_nogly_up'

# %%
plt.rcParams["font.family"] = "Times"
plt.rcParams['mathtext.fontset'] = 'cm'

# %% [markdown]
# ## Down to up (D2U)

# %%
d2u_dic = {1:{}, 2:{}, 3:{}, 4:{}, 5:{}}

for ii in range(2,7):
    for file in glob.iglob(f'ReportPlots/saltbridge_VMD/d2u-{ii}/*.dat'):
        fr = []
        dist = []
        fin = open(file,"r").read()
        for line in fin.split('\n'):
            if len(line)>0:
                fr.append(int(line.split(" ")[0]))
                dist.append(float(line.split(" ")[1]))
        fr = np.array(fr)
        dist= np.array(dist)
        tit = file.split('/')[-1]
        d2u_dic[ii-1][tit[7:-4]] = (fr, dist)

#         fig = plt.figure(figsize=[5,3])
#         ax = fig.add_subplot(111, aspect='auto')
#         plt.plot(fr*0.01, dist)
#         # plt.legend(loc='best')
#         plt.xlabel('Simualtion Time (ns)')
#         plt.ylabel('N-O Distance ($\mathrm{\AA}$)')
#         ax.set_title(f'{tit[7:-4]}')
#         plt.tight_layout()
#     #     plt.show()
#         plt.savefig(f'ReportPlots/saltbridge_VMD/d2u-{ii}/fig/{tit[7:-4]}.png', dpi=300)
#         plt.close()

# %%
fig = plt.figure(figsize=[5,3])
ax = fig.add_subplot(111, aspect='auto')
plt.plot(fr*0.1, dist)
# plt.legend(loc='best')
plt.xlabel('Simualtion Time (ns)')
plt.ylabel('N-O Distance ($\mathrm{\AA}$)')
tit = file.split('/')[-1]
ax.set_title(f'{tit[7:-4]}')
plt.tight_layout()
plt.show()
# plt.savefig(f'fig/{tit[7:-4]}.png')
# Out:
# <img src="data:image/png;base64,..." width="499.9999891627921">

# %%
files_d2u = [0, 0, 0, 0, 0]

for ii in range(2,7):
    files_d2u[ii-2] = []
    for file in glob.iglob(f'ReportPlots/saltbridge_VMD/d2u-{ii}/*.dat'):
        files_d2u[ii-2].append(file.split('/')[3])

# %% [markdown]
# Shared salt bridges in 5 replicates.

# %%
all_d2u = []

for this in files_d2u[0]:
    if (this in files_d2u[1]) and (this in files_d2u[2]) and (this in files_d2u[3]) and (this in files_d2u[4]):
        all_d2u.append(this)

# %%
# for fi in all_d2u:
#     fig = plt.figure(figsize=[6,4])
#     ax = fig.add_subplot(111, aspect='auto')
    
#     for jj in range(1,6):
#         fr, dist = d2u_dic[jj][fi[7:-4]]
#         plt.plot(fr*0.01, dist, label=f'rep {jj}')
        
#     plt.legend(loc='best')
#     plt.xlim(0, 4)
#     plt.xlabel('Simualtion Time (ns)')
#     plt.ylabel('N-O Distance ($\mathrm{\AA}$)')
#     ax.set_title(fi[7:-4]+' in Opening')
#     plt.tight_layout()
#     plt.show()

#     plt.savefig(f'ReportPlots/saltbridge_VMD/d2u-shared/fig/{fi[7:-4]}.png')
#     plt.close()
# Out:
# <img src="data:image/png;base64,..." width="599.9999869953505">
# <img src="data:image/png;base64,..." width="599.9999869953505">
# <img src="data:image/png;base64,..." width="599.9999869953505">
# <img src="data:image/png;base64,..." width="599.9999869953505">
# <img src="data:image/png;base64,..." width="599.9999869953505">
# <img src="data:image/png;base64,..." width="599.9999869953505">
# <img src="data:image/png;base64,..." width="599.9999869953505">
# <img src="data:image/png;base64,..." width="599.9999869953505">
# <img src="data:image/png;base64,..." width="599.9999869953505">
# <img src="data:image/png;base64,..." width="599.9999869953505">
# <img src="data:image/png;base64,..." width="599.9999869953505">
# <img src="data:image/png;base64,..." width="599.9999869953505">
# <img src="data:image/png;base64,..." width="599.9999869953505">
# <img src="data:image/png;base64,..." width="599.9999869953505">
# <img src="data:image/png;base64,..." width="599.9999869953505">
# ...

# %% [markdown]
# ## Up to down (U2D)

# %%
u2d_dic = {1:{}, 2:{}, 3:{}, 4:{}, 5:{}}

for ii in range(2,7):
    for file in glob.iglob(f'ReportPlots/saltbridge_VMD/u2d-{ii}/*.dat'):
        fr = []
        dist = []
        fin = open(file,"r").read()
        for line in fin.split('\n'):
            if len(line)>0:
                fr.append(int(line.split(" ")[0]))
                dist.append(float(line.split(" ")[1]))
        fr = np.array(fr)
        dist= np.array(dist)
        tit = file.split('/')[-1]
        u2d_dic[ii-1][tit[7:-4]] = (fr, dist)

#         fig = plt.figure(figsize=[5,3])
#         ax = fig.add_subplot(111, aspect='auto')
#         plt.plot(fr*0.01, dist)
#         # plt.legend(loc='best')
#         plt.xlabel('Simualtion Time (ns)')
#         plt.ylabel('N-O Distance ($\mathrm{\AA}$)')
#         ax.set_title(f'{tit[7:-4]}')
#         plt.tight_layout()
#     #     plt.show()
#         plt.savefig(f'ReportPlots/saltbridge_VMD/u2d-{ii}/fig/{tit[7:-4]}.png')
#         plt.close()

# %%
for i in range(1,6):
    u2d_dic[i]['ARG847-ASP40'] = u2d_dic[i]['ASP40-ARG847']
    u2d_dic[i]['ARG847-GLU281'] = u2d_dic[i]['GLU281-ARG847']
    d2u_dic[i]['ARG847-ASP40'] = d2u_dic[i]['ASP40-ARG847']
    d2u_dic[i]['ARG847-GLU281'] = d2u_dic[i]['GLU281-ARG847']

# %%
files_u2d = [0, 0, 0, 0, 0]

for ii in range(2,7):
    files_u2d[ii-2] = []
    for file in glob.iglob(f'ReportPlots/saltbridge_VMD/u2d-{ii}/*.dat'):
        files_u2d[ii-2].append(file.split("/")[3])

# %% [markdown]
# Shared salt bridges in 5 replicates.

# %%
all_u2d = []

for this in files_u2d[0]:
    if (this in files_u2d[1]) and (this in files_u2d[2]) and (this in files_u2d[3]) and (this in files_u2d[4]):
        all_u2d.append(this)

# %%
# for fi in all_u2d:
#     fig = plt.figure(figsize=[6,4])
#     ax = fig.add_subplot(111, aspect='auto')
    
#     for jj in range(1,6):
#         fr, dist = u2d_dic[jj][fi[7:-4]]
#         plt.plot(fr*0.01, dist, label=f'rep {jj}')
        
#     plt.legend(loc='best')
#     plt.xlim(0, 4)
#     plt.xlabel('Simualtion Time (ns)')
#     plt.ylabel('N-O Distance ($\mathrm{\AA}$)')
#     ax.set_title(fi[7:-4]+' in Closing')
#     plt.tight_layout()
# #     plt.show()

#     plt.savefig(f'ReportPlots/saltbridge_VMD/u2d-shared/fig/{fi[7:-4]}.png')
#     plt.close()

# %% [markdown]
# ## Post-processing

# %% [markdown]
# Sort saved pics into three categories: breaking, forming and discarding by looking at the curves' trend

# %%
u2d_break = []

for file in glob.iglob('ReportPlots/saltbridge_VMD/u2d-shared/fig/breaking/*.png'):
    u2d_break.append(file.split("/")[-1][:-4])

# %%
d2u_break = []

for file in glob.iglob('ReportPlots/saltbridge_VMD/d2u-shared/fig/breaking/*.png'):
    d2u_break.append(file.split("/")[-1][:-4])

# %%
u2d_form = []

for file in glob.iglob('ReportPlots/saltbridge_VMD/u2d-shared/fig/forming/*.png'):
    u2d_form.append(file.split("/")[-1][:-4])

# %%
d2u_form = []

for file in glob.iglob('ReportPlots/saltbridge_VMD/d2u-shared/fig/forming/*.png'):
    d2u_form.append(file.split("/")[-1][:-4])

# %%
u2d_form
# Out:
# ['ARG847-GLU281', 'ASP253-LYS77', 'ASP820-ARG815', 'ASP950-LYS310']

# %%
d2u_break
# Out:
# ['ASP820-ARG815', 'ARG847-GLU281', 'ASP253-LYS77', 'ASP950-LYS310']

# %%
def domains(name):
    fir = int(name.split('-')[0][3:])
    sec = int(name.split('-')[1][3:])
    
    if fir >= 27 and fir <= 304: 
        dfir = 'NTD'
    elif fir >= 305 and fir <= 328:
        dfir = 'SD1'
    elif fir >= 335 and fir <= 521:
        dfir = 'RBD'
    elif fir >= 522 and fir <= 672:
        dfir = 'SD2'
    elif fir >= 687 and fir <= 1146:
        dfir = 'S2'
    else:
        dfir = 'Loops'
        
    if sec >= 27 and sec <= 304: 
        dsec = 'NTD'
    elif sec >= 305 and sec <= 328:
        dsec = 'SD1'
    elif sec >= 335 and sec <= 521:
        dsec = 'RBD'
    elif sec >= 522 and sec <= 672:
        dsec = 'SD2'
    elif sec >= 687 and sec <= 1146:
        dsec = 'S2'
    else:
        dsec = 'Loops'
        
    return dfir+'-'+dsec

# %%
u2d_form_domain = []
for i in u2d_form:
    u2d_form_domain.append(domains(i))

# %%
u2d_break_domain = []
for i in u2d_break:
    u2d_break_domain.append(domains(i))

# %%
u2d_form
# Out:
# ['ARG847-GLU281', 'ASP253-LYS77', 'ASP820-ARG815', 'ASP950-LYS310']

# %%
u2d_form_domain
# Out:
# ['S2-NTD', 'NTD-NTD', 'S2-S2', 'S2-SD1']

# %%
u2d_break
# Out:
# ['ASP80-ARG21',
#  'ASP111-LYS113',
#  'ASP830-LYS304',
#  'ASP848-ARG44',
#  'ASP848-LYS304',
#  'ARG847-ASP40',
#  'GLU780-ARG1019',
#  'GLU1072-ARG1107',
#  'GLU819-ARG815']

# %%
u2d_break_domain
# Out:
# ['NTD-Loops',
#  'NTD-NTD',
#  'S2-NTD',
#  'S2-NTD',
#  'S2-NTD',
#  'S2-NTD',
#  'S2-S2',
#  'S2-S2',
#  'S2-S2']

# %% [markdown]
# Plot for the mean of 5 replicates

# %%
sbcolor = {'ASP111-LYS113':'red',
             'ASP253-LYS77': 'navy',
             'ARG847-ASP40':'brown',
             'ASP80-ARG21':'darkslategray',
             'ASP820-ARG815':'magenta',
             'ASP830-LYS304':'darkorange',
             'ASP848-ARG44':'olive',
             'ASP848-LYS304':'black',
             'ASP950-LYS310':'darkgreen',
             'GLU1072-ARG1107':'indigo',
             'ARG847-GLU281':'deeppink',
             'GLU780-ARG1019':'teal',
             'GLU819-ARG815':'goldenrod'}

sbcolorf = {'ASP111-LYS113':'lightsalmon',
             'ASP253-LYS77':'cornflowerblue',
             'ARG847-ASP40':'rosybrown',
             'ASP80-ARG21':'cadetblue',
             'ASP820-ARG815':'plum',
             'ASP830-LYS304':'bisque',
             'ASP848-ARG44':'khaki',
             'ASP848-LYS304':'gray',
             'ASP950-LYS310': 'limegreen',
             'GLU1072-ARG1107':'violet',
             'ARG847-GLU281':'pink',
             'GLU780-ARG1019':'lightblue',
             'GLU819-ARG815':'wheat'}

# %%
onekey = {'ASP':'D', 'GLU':'E', 'LYS':'K', 'ARG':'R'}

# %%
k = 0
# for fi in {'ASP820-ARG815'}:
for fi in d2u_break:
    dic = d2u_dic.copy()
    o_or_c = 'Opening'
    
    dist = np.zeros([5,400])
    for jj in range(1,6):
        dist[jj-1] = dic[jj][fi][1][:400]
        
    fig = plt.figure(figsize=[4,2.75])
    ax = fig.add_subplot(111, aspect='auto')
    plt.plot(np.arange(400)*0.01, np.mean(dist,axis=0), label=fi, color=sbcolor[fi])
    plt.fill_between(np.arange(400)*0.01, np.min(dist,axis=0), np.max(dist,axis=0), alpha=0.4, 
                     edgecolor=sbcolor[fi], facecolor=sbcolorf[fi], 
                     linewidth=0, linestyle='dashdot', antialiased=True)
    ax.tick_params(labelbottom=True, labeltop=False, labelleft=True, labelright=True,
               bottom=True, top=False, left=True, right=True)
    plt.xlim(0, 4)
    plt.xlabel('Simulation Time (ns)', fontsize=11)
    plt.ylabel('N-O Distance ($\mathrm{\AA}$)', fontsize=11)
    aaa = fi[:3]
    bbb = fi.split('-')[0][3:]
    ccc = fi.split('-')[1][:3]
    ddd = fi.split('-')[1][3:]
    ax.set_title(f'{onekey[aaa]+bbb}-{onekey[ccc]+ddd}' +' in ' + o_or_c +' Transitions', fontsize=12)
    plt.tight_layout()
    plt.savefig(f'ReportPlots/SaltBridgePlot/{o_or_c}_{fi}', dpi=300)
    plt.close()
    
    k += 1
# Out:
# <img src="data:image/png;base64,..." width="399.9999913302337">
# <img src="data:image/png;base64,..." width="399.9999913302337">
# <img src="data:image/png;base64,..." width="399.9999913302337">
# <img src="data:image/png;base64,..." width="399.9999913302337">

# %%
aaa, bbb, ccc, ddd
# Out:
# ('GLU', '773', 'ARG', '1019')

# %% [markdown]
# Find salt bridges in RBD

# %%
RBD_region = []
for fi in glob.iglob('ReportPlots/saltbridge_VMD/d2u-shared/fig/discard/*.png'):
    fii = fi.split("/")[-1]
    aaa = fii[:3]
    bbb = fii.split('-')[0][3:]
    ccc = fii.split('-')[1][:3]
    ddd = fii.split('-')[1][3:-4]

    if (int(bbb)>=335 and int(bbb)<=521) or (int(ddd)>=335 and int(ddd)<=521):
        RBD_region.append(fi)

# %%
RBD_region
# Out:
# ['saltbridge_VMD/d2u-shared/fig/discard\\ASP405-ARG403.png',
#  'saltbridge_VMD/d2u-shared/fig/discard\\ASP442-ARG509.png',
#  'saltbridge_VMD/d2u-shared/fig/discard\\ASP467-ARG454.png',
#  'saltbridge_VMD/d2u-shared/fig/discard\\ASP467-ARG457.png',
#  'saltbridge_VMD/d2u-shared/fig/discard\\ASP427-LYS424.png',
#  'saltbridge_VMD/d2u-shared/fig/discard\\ASP398-ARG355.png',
#  'saltbridge_VMD/d2u-shared/fig/discard\\ASP389-LYS528.png',
#  'saltbridge_VMD/d2u-shared/fig/discard\\ASP389-LYS386.png',
#  'saltbridge_VMD/d2u-shared/fig/discard\\ASP420-LYS424.png',
#  'saltbridge_VMD/d2u-shared/fig/discard\\GLU516-ARG357.png',
#  'saltbridge_VMD/d2u-shared/fig/discard\\GLU465-ARG466.png',
#  'saltbridge_VMD/d2u-shared/fig/discard\\GLU465-LYS462.png',
#  'saltbridge_VMD/d2u-shared/fig/discard\\GLU340-LYS356.png',
#  'saltbridge_VMD/d2u-shared/fig/discard\\ASP405-ARG408.png',
#  'saltbridge_VMD/d2u-shared/fig/discard\\GLU406-ARG403.png']
